# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
f = h5py.File('./heat_eqn.h5', 'r')
u0 = f['0.0/u'][:]
u1 = f['1.0/u'][:]
xh = f.attrs.get('x').flatten()
f.close()

# %%
plt.figure()
plt.imshow(u0)
plt.show()

# %%
plt.figure()
plt.plot(xh,u0[40])
plt.plot(xh,u1[40])
plt.grid()
plt.show()
